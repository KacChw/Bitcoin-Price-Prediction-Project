# %%
import yfinance as yf
import os
import pandas as pd

# %%
btc_ticker = yf.Ticker("BTC-USD")

# %%
btc = btc_ticker.history(period="max")
btc
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2026-05-08 00:00:00+00:00  80009.625000  80447.265625  79205.515625
# 2026-05-09 00:00:00+00:00  80187.742188  81030.062500  80119.929688
# 2026-05-10 00:00:00+00:00  80665.609375  82430.171875  80274.132812
# 2026-05-11 00:00:00+00:00  82139.046875  82326.234375  80451.421875
# 2026-05-12 00:00:00+00:00  81721.414062  81721.414062  80503.179688
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00    457.334015     21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00    424.440002     34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00    394.795990     37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00    408.903992     36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00    398.821014     26580100        0.0           0.0
# ...                                 ...          ...        ...           ...
# 2026-05-08 00:00:00+00:00  80186.765625  33789351540        0.0           0.0
# 2026-05-09 00:00:00+00:00  80664.367188  18102086996        0.0           0.0
# 2026-05-10 00:00:00+00:00  82138.929688  26965971077        0.0           0.0
# 2026-05-11 00:00:00+00:00  81728.296875  32409774919        0.0           0.0
# 2026-05-12 00:00:00+00:00  80700.882812  30598473728        0.0           0.0
#
# [4256 rows x 7 columns]

# %%
btc.index = pd.to_datetime(btc.index)

# %%
del btc["Dividends"]
del btc["Stock Splits"]

# %%
btc.columns = [c.lower() for c in btc.columns]

# %%
btc.plot.line(y="close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
wiki = pd.read_csv("wikipedia_edits.csv", index_col=0, parse_dates=True)

# %%
wiki
# Out:
#             edit_count  sentiment  neg_sentiment
# 2009-04-06    0.133333  -0.018351       0.025000
# 2009-04-07    0.000000   0.000000       0.000000
# 2009-04-08    0.000000   0.000000       0.000000
# 2009-04-09    0.000000   0.000000       0.000000
# 2009-04-10    0.000000   0.000000       0.000000
# ...                ...        ...            ...
# 2026-05-08    0.200000  -0.064791       0.116667
# 2026-05-09    0.200000  -0.064791       0.116667
# 2026-05-10    0.166667  -0.031988       0.083333
# 2026-05-11    0.166667  -0.031988       0.083333
# 2026-05-12    0.166667  -0.031988       0.083333
#
# [6246 rows x 3 columns]

# %%
# Usuwamy strefę czasową z indeksu btc 
if btc.index.tz is not None:
    btc.index = btc.index.tz_localize(None)
if wiki.index.tz is not None:
    wiki.index = wiki.index.tz_localize(None)

btc = btc.merge(wiki, left_index=True, right_index=True)
btc
# Out:
#                     open          high           low         close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2026-05-08  80009.625000  80447.265625  79205.515625  80186.765625
# 2026-05-09  80187.742188  81030.062500  80119.929688  80664.367188
# 2026-05-10  80665.609375  82430.171875  80274.132812  82138.929688
# 2026-05-11  82139.046875  82326.234375  80451.421875  81728.296875
# 2026-05-12  81721.414062  81721.414062  80503.179688  80700.882812
#
#                  volume  edit_count  sentiment  neg_sentiment
# Date
# 2014-09-17     21056800    5.033333  -0.232191       0.532718
# 2014-09-18     34483200    5.066667  -0.232760       0.532718
# 2014-09-19     37919700    5.200000  -0.235415       0.549385
# 2014-09-20     36863600    5.200000  -0.233185       0.549385
# 2014-09-21     26580100    5.233333  -0.204017       0.532718
# ...                 ...         ...        ...            ...
# 2026-05-08  33789351540    0.200000  -0.064791       0.116667
# 2026-05-09  18102086996    0.200000  -0.064791       0.116667
# 2026-05-10  26965971077    0.166667  -0.031988       0.083333
# 2026-05-11  32409774919    0.166667  -0.031988       0.083333
# 2026-05-12  30598473728    0.166667  -0.031988       0.083333
#
# [4256 rows x 8 columns]

# %%
btc["tomorrow"] = btc["close"].shift(-1)
btc
# Out:
#                     open          high           low         close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2026-05-08  80009.625000  80447.265625  79205.515625  80186.765625
# 2026-05-09  80187.742188  81030.062500  80119.929688  80664.367188
# 2026-05-10  80665.609375  82430.171875  80274.132812  82138.929688
# 2026-05-11  82139.046875  82326.234375  80451.421875  81728.296875
# 2026-05-12  81721.414062  81721.414062  80503.179688  80700.882812
#
#                  volume  edit_count  sentiment  neg_sentiment      tomorrow
# Date
# 2014-09-17     21056800    5.033333  -0.232191       0.532718    424.440002
# 2014-09-18     34483200    5.066667  -0.232760       0.532718    394.795990
# 2014-09-19     37919700    5.200000  -0.235415       0.549385    408.903992
# 2014-09-20     36863600    5.200000  -0.233185       0.549385    398.821014
# 2014-09-21     26580100    5.233333  -0.204017       0.532718    402.152008
# ...                 ...         ...        ...            ...           ...
# 2026-05-08  33789351540    0.200000  -0.064791       0.116667  80664.367188
# 2026-05-09  18102086996    0.200000  -0.064791       0.116667  82138.929688
# 2026-05-10  26965971077    0.166667  -0.031988       0.083333  81728.296875
# 2026-05-11  32409774919    0.166667  -0.031988       0.083333  80700.882812
# 2026-05-12  30598473728    0.166667  -0.031988       0.083333           NaN
#
# [4256 rows x 9 columns]

# %%
btc["target"] = (btc["tomorrow"] > btc["close"]).astype(int)

# %%
btc["target"].value_counts()
# Out:
# target
# 1    2235
# 0    2021
# Name: count, dtype: int64

# %%
#training part 
#baseline
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=50, random_state=1)

train = btc.iloc[:-200]
test = btc[-200:]

predictors = ["close", "volume", "open", "high", "low", "edit_count", "sentiment", "neg_sentiment"]
model.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["target"], preds)
# Out:
# 0.4296875

# %%
#improve accuracy
#adding backtesting
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="predictions")
    precision_score(test["target"], preds)
    combine = pd.concat([test["target"], preds], axis=1)
    return combine

# %%
def backtest(data, model, predictors, start=1095, step=150):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)
